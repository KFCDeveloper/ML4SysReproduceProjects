# %% [markdown]
#
# # Traffic gen. on fattree16
# $$\quad$$
#
#
#
#
#
#
# - [Section 1: Networking](#Networking)
# - [Section 2: Traffic gen. of deepQueueNet](#Traffic_generalization)
#
#
#  $$\quad$$
#
#
# >   This notebook is to use the trained device model, deepQueueNet, to make end-to-end inference on fattree topology with different traffic patterns:
# >  - MAP
# >  - Poisson
# >  - OnOff
# >
# > The task is deployed on 4 gpus.
#
#
#
# <html>
# <body>
# <div align="center">
# <img src="./assets/deploy.png" alt="deplo"  width="1000">
# </div>
# </body>
# </html>
#
# $$\quad$$
#  $$\quad$$

# %%
import warnings
warnings.filterwarnings("ignore")
from scipy import stats
import pandas as pd 
import numpy as np 
# %load_ext autoreload     
# %autoreload 2
from code_deepQueueNet.config import BaseConfig, modelConfig
from code_deepQueueNet.util import inference
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style('ticks')
# %matplotlib inline

# %% [markdown]
# # $\quad$
# # $\quad$
#
# ## Networking
#
#  ``Model Parameters``
# > __traffic_pattern__:  ['onoff', 'poisson', 'map']
# > __file__: rsim (obtained via DES) and rsim_pred (obtained via inference)

# %%
import warnings
warnings.filterwarnings("ignore")




traffic_pattern='map'
config=BaseConfig()
model_config=modelConfig()
for i in range(5):  # 5
    ins=inference.INFER('./data/fattree16/{}/rsim{}'.format(traffic_pattern, i+1), 
                         config, 
                         model_config)
    ins.run(gpu_number=4) #please set the value of gpu_number (1,2,4) accordingly.
# Out:
# 2023-12-15 00:54:55.432540: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-12-15 00:54:55.446610: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-12-15 00:54:55.461161: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-12-15 00:54:55.474458: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-12-15 00:54:55.497536: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1665] Found device 0 with properties:
# name: NVIDIA TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:03:00.0
# 2023-12-15 00:54:55.497604: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2023-12-15 00:54:55.502028: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2023-12-15 00:54:55.503207: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-12-15 00:54:55.503510: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-12-15 00:54:55.507934: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2023-12-15 00:54:55.509955: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2023-12-15 00:54:55.510140: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2023-12-15 00:54:55.534959: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1793] Adding visible gpu devices: 0
# 2023-12-15 00:54:55.545707: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1665] Found device 0 with properties:
# name: NVIDIA TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:02:00.0
# 2023-12-15 00:54:55.545781: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2023-12-15 00:54:55.550383: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2023-12-15 00:54:55.551582: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-12-15 00:54:55.551904: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-12-15 00:54:55.556401: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2023-12-15 00:54:55.558403: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2023-12-15 00:54:55.558592: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2023-12-15 00:54:55.570169: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2023-12-15 00:54:55.572654: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f6a5ade790 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-15 00:54:55.572693: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-15 00:54:55.580907: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1793] Adding visible gpu devices: 0
# 2023-12-15 00:54:55.587639: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1665] Found device 0 with properties:
# name: NVIDIA TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:82:00.0
# 2023-12-15 00:54:55.587699: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2023-12-15 00:54:55.592178: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2023-12-15 00:54:55.593416: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-12-15 00:54:55.593725: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-12-15 00:54:55.598209: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2023-12-15 00:54:55.600249: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2023-12-15 00:54:55.600443: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2023-12-15 00:54:55.609442: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2023-12-15 00:54:55.611218: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f6a5ade790 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-15 00:54:55.611245: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-15 00:54:55.621939: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1793] Adding visible gpu devices: 0
# 2023-12-15 00:54:55.631188: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1665] Found device 0 with properties:
# name: NVIDIA TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:83:00.0
# 2023-12-15 00:54:55.631264: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2023-12-15 00:54:55.635896: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2023-12-15 00:54:55.637172: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-12-15 00:54:55.637501: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-12-15 00:54:55.642089: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2023-12-15 00:54:55.644157: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2023-12-15 00:54:55.644397: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2023-12-15 00:54:55.651460: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2023-12-15 00:54:55.653296: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f6a5ade790 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-15 00:54:55.653323: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-15 00:54:55.956572: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1793] Adding visible gpu devices: 0
# 2023-12-15 00:54:55.984152: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2023-12-15 00:54:55.985847: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f6a5ade790 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-12-15 00:54:55.985874: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-12-15 00:54:56.508114: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f6a68b9ab0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-15 00:54:56.508161: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA TITAN Xp, Compute Capability 6.1
# 2023-12-15 00:54:56.520006: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1665] Found device 0 with properties:
# name: NVIDIA TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:02:00.0
# 2023-12-15 00:54:56.520117: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2023-12-15 00:54:56.520163: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2023-12-15 00:54:56.520201: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-12-15 00:54:56.520267: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-12-15 00:54:56.520302: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2023-12-15 00:54:56.520333: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2023-12-15 00:54:56.520365: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2023-12-15 00:54:56.521576: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f6a68b9ab0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-15 00:54:56.521603: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA TITAN Xp, Compute Capability 6.1
# 2023-12-15 00:54:56.525518: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1665] Found device 0 with properties:
# name: NVIDIA TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:03:00.0
# 2023-12-15 00:54:56.525722: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2023-12-15 00:54:56.525784: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2023-12-15 00:54:56.525830: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-12-15 00:54:56.525873: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-12-15 00:54:56.525916: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2023-12-15 00:54:56.525958: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2023-12-15 00:54:56.526001: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2023-12-15 00:54:56.527800: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1793] Adding visible gpu devices: 0
# 2023-12-15 00:54:56.527884: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2023-12-15 00:54:56.546717: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f6a68b9ab0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-15 00:54:56.546775: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA TITAN Xp, Compute Capability 6.1
# 2023-12-15 00:54:56.548210: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f6a68b9ab0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-15 00:54:56.548270: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA TITAN Xp, Compute Capability 6.1
# 2023-12-15 00:54:56.548810: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1793] Adding visible gpu devices: 0
# 2023-12-15 00:54:56.548933: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2023-12-15 00:54:56.553026: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1665] Found device 0 with properties:
# name: NVIDIA TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:82:00.0
# 2023-12-15 00:54:56.553156: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2023-12-15 00:54:56.553219: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2023-12-15 00:54:56.553270: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-12-15 00:54:56.553319: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-12-15 00:54:56.553370: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2023-12-15 00:54:56.553420: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2023-12-15 00:54:56.553454: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1665] Found device 0 with properties:
# name: NVIDIA TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:83:00.0
# 2023-12-15 00:54:56.553470: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2023-12-15 00:54:56.553528: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2023-12-15 00:54:56.553571: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2023-12-15 00:54:56.553608: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-12-15 00:54:56.553643: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-12-15 00:54:56.553679: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2023-12-15 00:54:56.553715: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2023-12-15 00:54:56.553750: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2023-12-15 00:54:56.560284: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1793] Adding visible gpu devices: 0
# 2023-12-15 00:54:56.560358: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2023-12-15 00:54:56.560396: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1793] Adding visible gpu devices: 0
# 2023-12-15 00:54:56.560471: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2023-12-15 00:54:56.915885: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1206] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-12-15 00:54:56.915954: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212]      0
# 2023-12-15 00:54:56.915962: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1225] 0:   N
# 2023-12-15 00:54:56.920695: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1351] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 11458 MB memory) -> physical GPU (device: 0, name: NVIDIA TITAN Xp, pci bus id: 0000:82:00.0, compute capability: 6.1)
# 2023-12-15 00:54:56.923603: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1206] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-12-15 00:54:56.923632: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212]      0
# 2023-12-15 00:54:56.923654: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1225] 0:   N
# 2023-12-15 00:54:56.925539: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1351] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 11445 MB memory) -> physical GPU (device: 0, name: NVIDIA TITAN Xp, pci bus id: 0000:02:00.0, compute capability: 6.1)
# 2023-12-15 00:54:56.943657: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1206] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-12-15 00:54:56.943710: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212]      0
# 2023-12-15 00:54:56.943719: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1225] 0:   N
# 2023-12-15 00:54:56.945746: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1351] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 11458 MB memory) -> physical GPU (device: 0, name: NVIDIA TITAN Xp, pci bus id: 0000:03:00.0, compute capability: 6.1)
# 2023-12-15 00:54:56.969905: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1206] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-12-15 00:54:56.969976: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212]      0
# 2023-12-15 00:54:56.969987: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1225] 0:   N
# 2023-12-15 00
I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# time used (total) 1.090681 min.

# %% [markdown]
# # $\quad$
# # $\quad$
#
# ## Traffic_generalization
#
#
#  Now, let's evaluate the traffic generalization of deepQueueNet on Fattree16.

# %%
import tqdm
import matplotlib.patches as mpatches
import pandas as pd
import scipy.stats as measures


def showFig(df):
    for col in ['delay', 'jitter']:
        fig,(ax) = plt.subplots(figsize=(8,5))
        a_val = 1.
        colors = ['r','b','g']
        circ1 = mpatches.Patch(edgecolor=colors[0],alpha=a_val,linestyle ='-',label='MAP - sim', fill=False)
        circ2 = mpatches.Patch(edgecolor=colors[0],alpha=a_val,linestyle ='--',label='MAP - prediction',fill=False)
        circ3 = mpatches.Patch(edgecolor=colors[1],alpha=a_val,linestyle ='-',label='Poisson - sim', fill=False)
        circ4 = mpatches.Patch(edgecolor=colors[1],alpha=a_val,linestyle='--', label='Poisson - prediction', fill=False)
        circ5 = mpatches.Patch(edgecolor=colors[2],alpha=a_val,linestyle ='-',label='Onoff - sim', fill=False)
        circ6 = mpatches.Patch(edgecolor=colors[2],alpha=a_val,linestyle='--', label='Onoff - prediction', fill=False)
        
        
        for i, c in zip(['MAP','Poisson','Onoff'], colors):
            bins=np.histogram(np.hstack((df[df.tp==i][col+'_sim'].values, 
                                         df[df.tp==i][col+'_pred'].values)), bins=100)[1]  
            plt.hist(df[df.tp==i][col+'_sim'].values, bins, density=True, color=c, histtype='step',  linewidth=1.5);
            plt.hist(df[df.tp==i][col+'_pred'].values, bins, density=True, color=c, histtype='step', linestyle='--', linewidth=1.5);
        ax.legend(handles = [circ1,circ2,circ3,circ4,circ5,circ6],loc=1, fontsize = 14)
        plt.xlabel(col.capitalize()+' (sec)', fontsize = 14)
        plt.ylabel('PDF', fontsize = 14)
        plt.tick_params(labelsize=12)
        
        
        fig,(ax) = plt.subplots(figsize=(8,5))
        for i, c in zip(['MAP','Poisson','Onoff'], colors):
            res=stats.relfreq(df[df.tp==i][col+'_sim'].values, numbins=100)
            x=res.lowerlimit + np.linspace(0, res.binsize*res.frequency.size, res.frequency.size)
            y=np.cumsum(res.frequency)
            plt.plot(x, y,color=c,  linewidth=1.5)
            res=stats.relfreq(df[df.tp==i][col+'_pred'].values, numbins=100)
            x=res.lowerlimit + np.linspace(0, res.binsize*res.frequency.size, res.frequency.size)
            y=np.cumsum(res.frequency)
            plt.plot(x, y,color=c, linestyle='--',   linewidth=1.5)
        plt.xlabel(col.capitalize()+' (sec)', fontsize = 14)
        plt.ylabel('CDF', fontsize = 14)
        ax.legend(handles = [circ1,circ2,circ3,circ4,circ5,circ6],loc=4, fontsize = 14)
        plt.tick_params(labelsize=12)
         
       
 
        
def mergeTrace():
    result=pd.DataFrame()
    for traffic_pattern in tqdm.tqdm(['onoff','poisson','map']):
        for filename in  ['rsim1', 'rsim2', 'rsim3', 'rsim4', 'rsim5']:
            t=pd.read_csv('./data/fattree16/{}/{}_pred.csv'.format(traffic_pattern, filename))
            t['delay_sim']=t['dep_time']-t['timestamp (sec)']   # dep_time 是 ground truth
            t['delay_pred']=t['etime']-t['timestamp (sec)']     # etime 是 dqn 算出来的
            t['fd']=t['path'].apply(lambda x: len(x.split('-'))) 
            t['jitter_sim']=t.groupby(['src_port', 'path'])['delay_sim'].diff().abs()
            t['jitter_pred']=t.groupby(['src_port', 'path'])['delay_pred'].diff().abs()
            if traffic_pattern=='map':
                t['tp']='MAP'
            else:
                t['tp']=traffic_pattern.capitalize()
            result=pd.concat([result, t], ignore_index=True)     
    return result 
             
    
result=mergeTrace()
showFig(result.dropna())
# Out:
# 100%|██████████| 3/3 [00:15<00:00,  5.18s/it]

# %% [markdown]
# # $\quad$

# %% [markdown]
# # $\quad$
